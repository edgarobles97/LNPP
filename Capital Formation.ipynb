# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("API_NE.GDI.TOTL.ZS_DS2_en_csv_v2_423968.csv")

# %%
data.set_index("Country Name", inplace = True)

# %%
data.head()
# Out:
#              Country Code      1960       1961       1962      1963  \
# Country Name
# Aruba                 ABW       NaN        NaN        NaN       NaN
# Afghanistan           AFG  16.11571  16.599198  19.105702  14.20119
# Angola                AGO       NaN        NaN        NaN       NaN
# Albania               ALB       NaN        NaN        NaN       NaN
# Andorra               AND       NaN        NaN        NaN       NaN
#
#                    1964       1965      1966      1967      1968  ...   \
# Country Name                                                      ...
# Aruba               NaN        NaN       NaN       NaN       NaN  ...
# Afghanistan   13.888894  11.258279  8.412698  5.179283  6.472492  ...
# Angola              NaN        NaN       NaN       NaN       NaN  ...
# Albania             NaN        NaN       NaN       NaN       NaN  ...
# Andorra             NaN        NaN       NaN       NaN       NaN  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, Aruba to Zimbabwe
# Data columns (total 61 columns):
# Country Code    264 non-null object
# 1960            82 non-null float64
# 1961            82 non-null float64
# 1962            83 non-null float64
# 1963            84 non-null float64
# 1964            85 non-null float64
# 1965            99 non-null float64
# 1966            102 non-null float64
# 1967            104 non-null float64
# 1968            106 non-null float64
# 1969            106 non-null float64
# 1970            127 non-null float64
# 1971            126 non-null float64
# 1972            127 non-null float64
# 1973            127 non-null float64
# 1974            127 non-null float64
# 1975            130 non-null float64
# 1976            133 non-null float64
# 1977            135 non-null float64
# 1978            135 non-null float64
# 1979            133 non-null float64
# 1980            144 non-null float64
# ...

# %%
filtro = ["Belgium","Czech Republic","France","Germany","Italy","Netherlands","Poland","Portugal","Romania",
          "Spain","Sweden","United Kingdom","Norway","Turkey",
          "Kazakhstan","Russian Federation","Ukraine","Uzbekistan","United States","Canada","Argentina","Brazil",
          "Chile","Colombia","Mexico","Venezuela, Bolivarian Republic of","China","India","Indonesia","Japan","Malaysia",
          "Korea, Republic of","Taiwan, Province of China","Thailand","Australia","New Zealand","Algeria","Egypt","Nigeria",
          "South Africa","Iran, Islamic Republic of","Kuwait","Saudi Arabia","United Arab Emirates"]

# %%
data2 = data.loc[filtro]
# Out:
# C:\Users\edari\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
data2.head(44)
# Out:
#                          Country Name Country Code       1960       1961  \
# 0                             Belgium          BEL        NaN        NaN
# 1                      Czech Republic          CZE        NaN        NaN
# 2                              France          FRA        NaN        NaN
# 3                             Germany          DEU        NaN        NaN
# 4                               Italy          ITA        NaN        NaN
# 5                         Netherlands          NLD        NaN        NaN
# 6                              Poland          POL        NaN        NaN
# 7                            Portugal          PRT        NaN        NaN
# 8                             Romania          ROU        NaN        NaN
# 9                               Spain          ESP        NaN        NaN
# 10                             Sweden          SWE        NaN        NaN
# 11                     United Kingdom          GBR        NaN        NaN
# ...

# %%
data2 = data2.reset_index()

# %%
data_tidy = pd.melt(data2, id_vars = ['Country Code', 'Country Name'], var_name = ['year'], value_name = 'cap_for')

# %%
data_tidy = data_tidy.set_index(['Country Name', 'Country Code']).sort_index()

# %%
data_tidy.to_csv('capital_formation.csv', sep = ',')
