# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
url = 'https://en.wikipedia.org/wiki/Term_of_office'
r = requests.get(url)
r.encoding ='UTF-8'
soup = BeautifulSoup(r.text, 'lxml')

# %%
table = soup.find('table', attrs= {'class': 'wikitable sortable'})

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
data = []
rows = table.find_all('tr')

# %%
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append(ele for ele in cols if ele)

# %%
tab = pd.DataFrame(data)

# %%
tab.head(200)
# Out:
#                                                    Head of State Head of Government Members of the upper House Members of the lower (or sole house)
# Country
# Afghanistan                                                                       5                 3, 4 and 5                                    5
# Albania                                                                           5                        N/A                                    4
# Algeria                                                                           5                          6                                    5
# Andorra                           Until removed from office (Bishop of Urgel); 5...                        N/A                                    4
# Angola                                                                            5                        N/A                                    5
# ...

# %%
tab.columns = ["Country","Head of State Head of Government", "Members of the upper House", "Members of the lower (or sole house)"]

# %%
tab.drop(0, inplace = True)

# %%
main_list
# Out:
# array([], dtype='<U20')

# %%
filtro  = ["Belgium"
,"Czech Republic"
,"France"
,"Germany"
,"Italy[2]"
,"Netherlands"
,"Poland"
,"Portugal"
,"Romania"
,"Spain"
,"Sweden"
,"United Kingdom"
,"Norway"
,"Turkey"
,"Kazakhstan"
,"Russia"
,"Ukraine"
,"Uzbekistan"
,"United States"
,"Canada"
,"Argentina"
,"Brazil"
,"Chile"
,"Colombia"
,"Mexico"
,"Venezuela"
,"China"
,"India"
,"Indonesia"
,"Japan"
,"Malaysia"
,"South Korea"
,"Taiwan"
,"Thailand"
,"Australia"
,"New Zealand"
,"Algeria"
,"Egypt"
,"Nigeria"
,"South Africa"
,"Iran"
,"Kuwait"
,"Saudi Arabia"
,"United Arab Emirates"]

# %%
tab.set_index('Country')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-dc455d96b85c> in <module>
# ----> 1 tab.set_index('Country')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
lista = tab['Country'].unique()

# %%
main_list = np.setdiff1d(filtro,lista)

# %%
tab_final = tab.loc[filtro]

# %%
tab_final['Country Code'] = [
"BE",
"CZ",
"FR",
"DE",
"IT",
"NL",
"PL",
"PT",
"RO",
"ES",
"SE",
"GB",
"NO",
"TR",
"KZ",
"RU",
"UA",
"UZ",
"US",
"CA",
"AR",
"BR",
"CL",
"CO",
"MX",
"VE",
"CN",
"IN",
"ID",
"JP",
"MY",
"KR",
"TW",
"TH",
"AU",
"NZ",
"DZ",
"EG",
"NG",
"ZA",
"IR",
"KW",
"SA",
"AE"
]

# %%
tab_final.head()
# Out:
#                Head of State Head of Government Members of the upper House Members of the lower (or sole house) Country Code
# Country
# Belgium               Until removed from office                          5                                    5           BE
# Czech Republic                                5                          6                                    4           CZ
# France                                        5                          6                                    5           FR
# Germany                                       5                     4 to 5                                    4           DE
# Italy[2]                                      7                          5                                    5           IT

# %%
tab_final.to_csv("electoral_cycles.csv", sep = ',')
